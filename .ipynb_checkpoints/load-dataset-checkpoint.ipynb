# %% [markdown]
# # load dataset
#
# Carregando o dataset gerado e visualizando sua estrutura de dados usando a biblioteca Pandas.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from random import sample

# %%
# carrega o dataset passando o caminho do arquivo e informando qual é o separador utilizado entre as colunas, que nesse caso é a virgula.
dataset = pd.read_csv('/home/rodriguesfas/Workspace/My-K-NN/data/out/generated-polarity-train.csv', sep=',')

# %%
# Outra forma de visualização.

# cria um data frame atribuindo o dataset e o cabeçalho.
data_frame = pd.DataFrame(dataset)
data_frame.columns = ['document', 'label']

# visualiza dados 'tabela'
data_frame
# Out:
#                                               document  label
# 0    among multitud erotic thrill released early wo...      0
# 1    vari film seen seattl film festiv truethre  ra...      0
# 2    sight direc steven sorderbergh baffl hell lime...      0
# 3    hong kong cinem going  spell last productiom e...      0
# 4    supposedly based  story british driv build rai...      0
# 5    eight millimet really wholesom surveillanc   s...      0
# 6    currently accepting futur  drew barrymor chara...      0
# 7    direc nightm christm said preview guessing sai...      0
# 8    quest camelot warn  first featur length fully ...      0
# 9    movi just skip daught really   favorit martian...      0
# 10   crowd pleasing romantic movi stat  lead  toget...      0
# 11   forgiv fevered criticism ferv crucibl infect  ...      0
# 12   really starting wond alic silverston   beautif...      0
# 13   thing american film industry avoid cost  letti...      0
# ...

# %%
data_frame = data_frame.take(np.random.permutation(len(data_frame)))
data_frame
# Out:
#                                               document  label
# 65   recent onslaught film noir popped multiplex ev...      0
# 51   great anticipation  view braveheart last week ...      0
# 105  walked crouching  hidden dragon thought just s...      1
# 165  seen framed  rabbit  remembering much besid li...      1
# 24   susan grang review watch univers just need ano...      0
# 79   amer  convenienc cultur invented cell phon hou...      0
# 169  accepting  produc  best pictur winn saul zaent...      1
# 94   anoth formul feel good quirky comedy british  ...      0
# 20   reinde  easily worst thre recent film penned e...      0
# 136  fernand montenegr  behind  shift desk   train ...      1
# 119  rated though feel likely  mart  violenc thre m...      1
# 26   mighty  young blund nearly twenty minut actual...      0
# 76   might keep awak night creepy imagery bizarr vi...      0
# 0    among multitud erotic thrill released early wo...      0
# ...

# %%
# A variável dataset agora se tornou um dataframe.
# O DataFrame é uma estrutura de dados com duas dimensões onde linha podem ter colunas de tipos diferentes.
# Os dataframes são objetos extremamentes flexíveis, podendo armazenar listas, vetores e até outros dataframes.
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
# Imprime algumas linhas do dataset.
dataset.head()
# Out:
#                                             document  label
# 0  among multitud erotic thrill released early wo...      0
# 1  vari film seen seattl film festiv truethre  ra...      0
# 2  sight direc steven sorderbergh baffl hell lime...      0
# 3  hong kong cinem going  spell last productiom e...      0
# 4  supposedly based  story british driv build rai...      0

# %%
# imprime as colunas do dataset.
dataset.columns
# Out:
# Index(['document', 'label'], dtype='object')

# %%
len(dataset.columns)
# Out:
# 2

# %%
# Exibe quantas linhas tem todo o dataset.
dataset.count()
# Out:
# document    199
# label       199
# dtype: int64

# %%
# Realiza algumas análises estatísticas do dataset como: desvio padão, média, valor mínimo e máximom, entre outros.
dataset.describe()
# Out:
#             label
# count  199.000000
# mean     0.502513
# std      0.501255
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      1.000000
# max      1.000000

# %%
# o dataset deve ter cabeçalho.
pd.value_counts(dataset['document'])

# %%
plt.hist(x, bins=20)
plt.ylabel('No of times')
plt.show()
